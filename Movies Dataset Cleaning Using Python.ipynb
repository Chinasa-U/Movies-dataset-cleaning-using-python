# %% [markdown]
# # Movies Dataset Cleaning using Python
#     By  Annabel Chinasa .U

# %% [markdown]
# Movies dataset is made of movies activities and those variable contains some inconsistent data type, missing values, unwanted columns e.t.c. This  project focuses on cleaning the dataset because uncleaned dataset isn't good for Analysis.

# %%
#import pandas and numpy package
import pandas as pd
import numpy as np
import re
pd.options.mode.chained_assignment = None

# %%
#import movie dataset
movies = pd.read_csv('movies.csv')

# %%
#view the dataset
movies.head()
# Out:
#    Unnamed: 0 IMBD title ID            Original titlÊ  Release year  \
# 0           0     tt0111161  The Shawshank Redemption    1995-02-10
# 1           1     tt0068646             The Godfather    09 21 1972
# 2           2     tt0468569           The Dark Knight   23 -07-2008
# 3           3     tt0071562    The Godfather: Part II    1975-09-25
# 4           4     tt0110912              Pulp Fiction    1994-10-28
#
#                  Genrë¨ Duration Country Content Rating              Director  \
# 0                 Drama      142     USA              R        Frank Darabont
# 1          Crime, Drama      175     USA              R  Francis Ford Coppola
# 2  Action, Crime, Drama      152      US          PG-13     Christopher Nolan
# 3          Crime, Drama      220     USA              R  Francis Ford Coppola
# 4          Crime, Drama              USA              R     Quentin Tarantino
#
#    Unnamed: 8         Income     Votes  Score
# 0         NaN     $ 28815245  2.278.845   9.3
# 1         NaN    $ 246120974  1.572.674   9.2
# 2         NaN   $ 1005455211  2.241.615    9.
# 3         NaN  $ 4o8,035,783  1.098.714  9,.0
# 4         NaN    $ 222831817  1.780.147  8,9f

# %% [markdown]
# *This following process will be carried out to clean the movies dataset;*

# %% [markdown]
# - *Change all column names to lowercase*
# - *Change the special letter in the column*
# - *Remove apostrophe from genre column name*
# - *Remove the unnamed columns*
# - *Check duplicates and remove if any*
# - *Check and delete empty rows*
# - *Rename the columns*
# - *Extract the year from release_year*
# - *Select only the first genre in the genre column*
# - *Fill in the null value with correct year for release year*
# - *Fill in the null value with correct duration for duration column*
# - *Uniform the data in country column*
# - *Replace the R to rated and no value to not rated  and approved with rated in the rated column*
# - *Remove special character from income column and confirm the data type is an integer*
# - *Remove special character from votes column and confirm the data type is an integer*
# - *Remove unnecessary special numbers,commas and letters from score columns*
# - *Trim all the columns to remove spaces*

# %% [markdown]
# Inspecting the dataset to observe the variables of the  data.

# %%
#view the info of the dataset
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      101 non-null    int64
#  1   IMBD title ID   100 non-null    object
#  2   Original titlÊ  100 non-null    object
#  3   Release year    100 non-null    object
#  4   Genrë¨          100 non-null    object
#  5   Duration        99 non-null     object
#  6   Country         100 non-null    object
#  7   Content Rating  77 non-null     object
#  8   Director        100 non-null    object
#  9   Unnamed: 8      0 non-null      float64
#  10  Income          100 non-null    object
#  11   Votes          100 non-null    object
#  12  Score           100 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.4+ KB

# %% [markdown]
# *The info shows that the dataset contains 13 columns ans 102 rows. it also indicates that duration and content rating columns contains null values. The movies dataset also contains empty columns and lastly the dataset is made up of 1 float, 1 integer, 11 objects data types.*

# %% [markdown]
# ## <center> 1.Change all column names to Lowercase

# %%
#convert  all the header columns to lowercase
movies.columns = movies.columns.str.lower()

# %%
#show the dataset
movies.head(2)
# Out:
#    unnamed: 0 imbd title id            original titlê release year  \
# 0           0     tt0111161  The Shawshank Redemption   1995-02-10
# 1           1     tt0068646             The Godfather   09 21 1972
#
#          genrë¨ duration country content rating              director  \
# 0         Drama      142     USA              R        Frank Darabont
# 1  Crime, Drama      175     USA              R  Francis Ford Coppola
#
#    unnamed: 8       income     votes  score
# 0         NaN   $ 28815245  2.278.845   9.3
# 1         NaN  $ 246120974  1.572.674   9.2

# %% [markdown]
# ## <center> 2.Change the special letter in the header.

# %%
#import unidecode
from unidecode import unidecode

# %%
#remove the speial character in the header cloumns
movies.columns = [unidecode(col) for col in movies.columns]

#show the dataset
movies.head(2)
# Out:
#    unnamed: 0 imbd title id            original title release year  \
# 0           0     tt0111161  The Shawshank Redemption   1995-02-10
# 1           1     tt0068646             The Godfather   09 21 1972
#
#          genre" duration country content rating              director  \
# 0         Drama      142     USA              R        Frank Darabont
# 1  Crime, Drama      175     USA              R  Francis Ford Coppola
#
#    unnamed: 8       income     votes  score
# 0         NaN   $ 28815245  2.278.845   9.3
# 1         NaN  $ 246120974  1.572.674   9.2

# %% [markdown]
# ## <center>3.Remove apostrophe from genre column name.

# %%
#replace apostrophe with empty space
movies.columns = movies.columns.str.replace('"', '')

#show the dataset
movies.head(2)
# Out:
#    unnamed: 0 imbd title id            original title release year  \
# 0           0     tt0111161  The Shawshank Redemption   1995-02-10
# 1           1     tt0068646             The Godfather   09 21 1972
#
#           genre duration country content rating              director  \
# 0         Drama      142     USA              R        Frank Darabont
# 1  Crime, Drama      175     USA              R  Francis Ford Coppola
#
#    unnamed: 8       income     votes  score
# 0         NaN   $ 28815245  2.278.845   9.3
# 1         NaN  $ 246120974  1.572.674   9.2

# %% [markdown]
# ## <center>4. Remove the unnamed columns.

# %%
#Drop the unnamed colums
movies = movies.drop(['unnamed: 0','unnamed: 8'], axis=True)

#show dataset
movies.head(2)
# Out:
#   imbd title id            original title release year         genre duration  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10         Drama      142
# 1     tt0068646             The Godfather   09 21 1972  Crime, Drama      175
#
#   country content rating              director       income     votes  score
# 0     USA              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1     USA              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %% [markdown]
# ## <center>5. Rename the columns names

# %%
#rename the columns name
movies=movies.rename(columns={"imbd title id" : "title_id","original title" : "title",
                              "release year":"release_year", "content rating" : "content_rating"})

#show dataset
movies.head(2)
# Out:
#     title_id                     title release_year         genre duration  \
# 0  tt0111161  The Shawshank Redemption   1995-02-10         Drama      142
# 1  tt0068646             The Godfather   09 21 1972  Crime, Drama      175
#
#   country content_rating              director       income     votes  score
# 0     USA              R        Frank Darabont   $ 28815245  2.278.845   9.3
# 1     USA              R  Francis Ford Coppola  $ 246120974  1.572.674   9.2

# %% [markdown]
# ## <center>6. Check duplicates and remove if any

# %%
#find duplicate
duplicates = movies.duplicated()

# Count the number of duplicates
num_duplicates = duplicates.sum()

# Print the number of duplicates
print(f'The dataset contains {num_duplicates} duplicates.')
# Out:
# The dataset contains 0 duplicates.

# %% [markdown]
# ## <center>7. Check and delete empty row

# %%
# Check if any row is empty
is_empty = movies.isnull().all(axis=1).any()

if is_empty:
    print('The dataset contains at least one empty row.')
else:
    print('The dataset does not contain any empty row.')
# Out:
# The dataset contains at least one empty row.

# %%
#drop down empty rows
movies = movies.dropna(how='all')

# Count the number of rows in the DataFrame
num_rows = movies.shape[0]

# Print the number of rows
print(f'The dataset contains {num_rows} rows.')
# Out:
# The dataset contains 100 rows.

# %% [markdown]
# ## <center>8. Extract the year from the release_year

# %%
#change the release year to string
movies['release_year'] = movies['release_year'].astype(str)

# %%
#create pattern
pattern = r'(\d{4})'

# %%
#replace the previous year column with the year pattern created
movies['release_year'] = movies['release_year'].str.extract(pattern)

# %%
#show the dataset
movies.head()
# Out:
#     title_id                     title release_year                 genre  \
# 0  tt0111161  The Shawshank Redemption         1995                 Drama
# 1  tt0068646             The Godfather         1972          Crime, Drama
# 2  tt0468569           The Dark Knight         2008  Action, Crime, Drama
# 3  tt0071562    The Godfather: Part II         1975          Crime, Drama
# 4  tt0110912              Pulp Fiction         1994          Crime, Drama
#
#   duration country content_rating              director         income  \
# 0      142     USA              R        Frank Darabont     $ 28815245
# 1      175     USA              R  Francis Ford Coppola    $ 246120974
# 2      152      US          PG-13     Christopher Nolan   $ 1005455211
# 3      220     USA              R  Francis Ford Coppola  $ 4o8,035,783
# 4              USA              R     Quentin Tarantino    $ 222831817
#
#       votes  score
# 0  2.278.845   9.3
# 1  1.572.674   9.2
# 2  2.241.615    9.
# 3  1.098.714  9,.0
# 4  1.780.147  8,9f

# %% [markdown]
# ## <center>  9. Select only the first genre in the genre column

# %%
#use split to select the first genre
movies['genre'] = movies['genre'].str.split(',').str[0].str.strip()

#show the dataset
movies.head(10)
# Out:
#     title_id                                          title release_year  \
# 0  tt0111161                       The Shawshank Redemption         1995
# 1  tt0068646                                  The Godfather         1972
# 2  tt0468569                                The Dark Knight         2008
# 3  tt0071562                         The Godfather: Part II         1975
# 4  tt0110912                                   Pulp Fiction         1994
# 5  tt0167260  The Lord of the Rings: The Return of the King          NaN
# 6  tt0108052                               Schindler's List         1994
# 7  tt0050083                                   12 Angry Men         1957
# 8  tt1375666                                      Inception         2010
# 9  tt0137523                                     Fight Club          NaN
#
#        genre duration      country content_rating              director  \
# 0      Drama      142          USA              R        Frank Darabont
# 1      Crime      175          USA              R  Francis Ford Coppola
# 2     Action      152           US          PG-13     Christopher Nolan
# 3      Crime      220          USA              R  Francis Ford Coppola
# 4      Crime                   USA              R     Quentin Tarantino
# 5     Action      201  New Zealand          PG-13         Peter Jackson
# 6  Biography      Nan          USA              R      Steven Spielberg
# 7      Crime       96          USA      Not Rated          Sidney Lumet
# 8     Action      148          USA          PG-13     Christopher Nolan
# 9      Drama      Inf           UK              R         David Fincher
#
#           income     votes  score
# 0     $ 28815245  2.278.845   9.3
# 1    $ 246120974  1.572.674   9.2
# 2   $ 1005455211  2.241.615    9.
# 3  $ 4o8,035,783  1.098.714  9,.0
# 4    $ 222831817  1.780.147  8,9f
# 5   $ 1142271098  1.604.280  08.9
# 6    $ 322287794  1.183.248   8.9
# 7          $ 576    668.473   8.9
# 8    $ 869784991  2.002.816  8..8
# 9    $ 101218804  1.807.440   8.8

# %% [markdown]
# ## <center> 10. Fill in the null values in the release year with the correct year for release year

# %%
#use loc to input the value
movies.loc[5, 'release_year'] = '2003'
movies.loc[9, 'release_year'] = '1999'
movies.loc[15, 'release_year'] = '2001'
movies.loc[45, 'release_year'] = '1943'

#show the dataset
movies.head(10)
# Out:
#     title_id                                          title release_year  \
# 0  tt0111161                       The Shawshank Redemption         1995
# 1  tt0068646                                  The Godfather         1972
# 2  tt0468569                                The Dark Knight         2008
# 3  tt0071562                         The Godfather: Part II         1975
# 4  tt0110912                                   Pulp Fiction         1994
# 5  tt0167260  The Lord of the Rings: The Return of the King         2003
# 6  tt0108052                               Schindler's List         1994
# 7  tt0050083                                   12 Angry Men         1957
# 8  tt1375666                                      Inception         2010
# 9  tt0137523                                     Fight Club         1999
#
#        genre duration      country content_rating              director  \
# 0      Drama      142          USA              R        Frank Darabont
# 1      Crime      175          USA              R  Francis Ford Coppola
# 2     Action      152           US          PG-13     Christopher Nolan
# 3      Crime      220          USA              R  Francis Ford Coppola
# 4      Crime                   USA              R     Quentin Tarantino
# 5     Action      201  New Zealand          PG-13         Peter Jackson
# 6  Biography      Nan          USA              R      Steven Spielberg
# 7      Crime       96          USA      Not Rated          Sidney Lumet
# 8     Action      148          USA          PG-13     Christopher Nolan
# 9      Drama      Inf           UK              R         David Fincher
#
#           income     votes  score
# 0     $ 28815245  2.278.845   9.3
# 1    $ 246120974  1.572.674   9.2
# 2   $ 1005455211  2.241.615    9.
# 3  $ 4o8,035,783  1.098.714  9,.0
# 4    $ 222831817  1.780.147  8,9f
# 5   $ 1142271098  1.604.280  08.9
# 6    $ 322287794  1.183.248   8.9
# 7          $ 576    668.473   8.9
# 8    $ 869784991  2.002.816  8..8
# 9    $ 101218804  1.807.440   8.8

# %% [markdown]
# ## <center> 11. Fill in the null value with correct duration in duration column

# %%
#use loc to input the value
movies.loc[4, 'duration'] = '154'
movies.loc[6, 'duration'] = '195'
movies.loc[9, 'duration'] = '139'
movies.loc[11, 'duration'] = '178'
movies.loc[14, 'duration'] = '136'
movies.loc[16, 'duration'] = '124'
movies.loc[18, 'duration'] = '133'

#show the dataset
movies.head(10)
# Out:
#     title_id                                          title release_year  \
# 0  tt0111161                       The Shawshank Redemption         1995
# 1  tt0068646                                  The Godfather         1972
# 2  tt0468569                                The Dark Knight         2008
# 3  tt0071562                         The Godfather: Part II         1975
# 4  tt0110912                                   Pulp Fiction         1994
# 5  tt0167260  The Lord of the Rings: The Return of the King         2003
# 6  tt0108052                               Schindler's List         1994
# 7  tt0050083                                   12 Angry Men         1957
# 8  tt1375666                                      Inception         2010
# 9  tt0137523                                     Fight Club         1999
#
#        genre duration      country content_rating              director  \
# 0      Drama      142          USA              R        Frank Darabont
# 1      Crime      175          USA              R  Francis Ford Coppola
# 2     Action      152           US          PG-13     Christopher Nolan
# 3      Crime      220          USA              R  Francis Ford Coppola
# 4      Crime      154          USA              R     Quentin Tarantino
# 5     Action      201  New Zealand          PG-13         Peter Jackson
# 6  Biography      195          USA              R      Steven Spielberg
# 7      Crime       96          USA      Not Rated          Sidney Lumet
# 8     Action      148          USA          PG-13     Christopher Nolan
# 9      Drama      139           UK              R         David Fincher
#
#           income     votes  score
# 0     $ 28815245  2.278.845   9.3
# 1    $ 246120974  1.572.674   9.2
# 2   $ 1005455211  2.241.615    9.
# 3  $ 4o8,035,783  1.098.714  9,.0
# 4    $ 222831817  1.780.147  8,9f
# 5   $ 1142271098  1.604.280  08.9
# 6    $ 322287794  1.183.248   8.9
# 7          $ 576    668.473   8.9
# 8    $ 869784991  2.002.816  8..8
# 9    $ 101218804  1.807.440   8.8

# %% [markdown]
# ## <center>12. Uniform the data in country column

# %%
#show the unique values in country column
movies['country'].unique()
# Out:
# array(['USA', 'US', 'New Zealand', 'UK', 'New Zesland', 'Italy',
#        'New Zeland', 'US.', 'Brazil', 'Japan', 'Italy1', 'South Korea',
#        'France', 'Germany', 'India', 'Denmark', 'West Germany', 'Iran'],
#       dtype=object)

# %%
#use replace to mae the data consistent
movies['country'] = movies['country'].replace('US', 'USA')
movies['country'] = movies['country'].replace('US.', 'USA')
movies['country'] = movies['country'].replace('New Zesland', 'New Zealand')
movies['country'] = movies['country'].replace('New Zeland', 'New Zealand')
movies['country'] = movies['country'].replace('Italy1', 'Italy')

#show the dataset
movies.head(4)
# Out:
#     title_id                     title release_year   genre duration country  \
# 0  tt0111161  The Shawshank Redemption         1995   Drama      142     USA
# 1  tt0068646             The Godfather         1972   Crime      175     USA
# 2  tt0468569           The Dark Knight         2008  Action      152     USA
# 3  tt0071562    The Godfather: Part II         1975   Crime      220     USA
#
#   content_rating              director         income     votes  score
# 0              R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1              R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2          PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3              R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0

# %% [markdown]
# ## 13. Replace the R to restricted and no value to not rated and approved with general in the rated column

# %%
movies['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'Not Rated', 'Approved', 'PG', nan, 'Unrated', 'G'],
#       dtype=object)

# %%
#use replace to make the dataset consistent
movies['content_rating'] = movies['content_rating'].replace('R', 'Restricted')
movies['content_rating'] = movies['content_rating'].replace('Unrated', 'Not Rated')
movies['content_rating'] = movies['content_rating'].replace('PG', 'Parental Guidance')
movies['content_rating'] = movies['content_rating'].replace('G', 'General')
movies['content_rating'] = movies['content_rating'].replace('Approved', 'General')
movies['content_rating'] = movies['content_rating'].replace('PG-13', 'Parents Strongly Cautioned')
movies['content_rating'] = movies['content_rating'].replace('nan', 'Not Rated')
movies['content_rating'].fillna('Not rated', inplace=True)

#show the dataset
movies.head()
# Out:
#     title_id                     title release_year   genre duration country  \
# 0  tt0111161  The Shawshank Redemption         1995   Drama      142     USA
# 1  tt0068646             The Godfather         1972   Crime      175     USA
# 2  tt0468569           The Dark Knight         2008  Action      152     USA
# 3  tt0071562    The Godfather: Part II         1975   Crime      220     USA
# 4  tt0110912              Pulp Fiction         1994   Crime      154     USA
#
#                content_rating              director         income     votes   \
# 0                  Restricted        Frank Darabont     $ 28815245  2.278.845
# 1                  Restricted  Francis Ford Coppola    $ 246120974  1.572.674
# 2  Parents Strongly Cautioned     Christopher Nolan   $ 1005455211  2.241.615
# 3                  Restricted  Francis Ford Coppola  $ 4o8,035,783  1.098.714
# 4                  Restricted     Quentin Tarantino    $ 222831817  1.780.147
#
#   score
# 0   9.3
# 1   9.2
# 2    9.
# 3  9,.0
# 4  8,9f

# %% [markdown]
# ## <center>14. Remove special character from income column and confirm the data type is an integer

# %%
movies['income'].dtype
# Out:
# dtype('O')

# %%
#replace the special character and inappriopriate values
movies['income'] = movies['income'].astype(str).str.replace('$', '', regex=True).str.replace(',', '', 
                                                                    regex=True).str.replace('o', '0', regex=True).astype(float)

#format the incom data type
movies['income'] = movies['income'].fillna(0).astype(int)
movies['income'] = movies['income'].map('{:,.0f}'.format)

#show the dataset
movies.head()
# Out:
#     title_id                     title release_year   genre duration country  \
# 0  tt0111161  The Shawshank Redemption         1995   Drama      142     USA
# 1  tt0068646             The Godfather         1972   Crime      175     USA
# 2  tt0468569           The Dark Knight         2008  Action      152     USA
# 3  tt0071562    The Godfather: Part II         1975   Crime      220     USA
# 4  tt0110912              Pulp Fiction         1994   Crime      154     USA
#
#                content_rating              director         income     votes   \
# 0                  Restricted        Frank Darabont     28,815,245  2.278.845
# 1                  Restricted  Francis Ford Coppola    246,120,974  1.572.674
# 2  Parents Strongly Cautioned     Christopher Nolan  1,005,455,211  2.241.615
# 3                  Restricted  Francis Ford Coppola    408,035,783  1.098.714
# 4                  Restricted     Quentin Tarantino    222,831,817  1.780.147
#
#   score
# 0   9.3
# 1   9.2
# 2    9.
# 3  9,.0
# 4  8,9f

# %% [markdown]
# ## 15.  Remove special character from votes column and convert the data type to integer

# %%
#strip the data type
movies.columns = movies.columns.str.strip()

# %%
#replace the special values
movies['votes'] = movies['votes'].astype(str).str.replace('.', '', regex=True).str.replace(',', '.', regex=True).astype(int)

#format the datatype
movies['votes'] = movies['votes'].map('{:,.0f}'.format)

#show the dataset
movies.head()
# Out:
#     title_id                     title release_year   genre duration country  \
# 0  tt0111161  The Shawshank Redemption         1995   Drama      142     USA
# 1  tt0068646             The Godfather         1972   Crime      175     USA
# 2  tt0468569           The Dark Knight         2008  Action      152     USA
# 3  tt0071562    The Godfather: Part II         1975   Crime      220     USA
# 4  tt0110912              Pulp Fiction         1994   Crime      154     USA
#
#                content_rating              director         income      votes  \
# 0                  Restricted        Frank Darabont     28,815,245  2,278,845
# 1                  Restricted  Francis Ford Coppola    246,120,974  1,572,674
# 2  Parents Strongly Cautioned     Christopher Nolan  1,005,455,211  2,241,615
# 3                  Restricted  Francis Ford Coppola    408,035,783  1,098,714
# 4                  Restricted     Quentin Tarantino    222,831,817  1,780,147
#
#   score
# 0   9.3
# 1   9.2
# 2    9.
# 3  9,.0
# 4  8,9f

# %% [markdown]
# ## <center> 16. Remove unnecessary special numbers,commas and letters from score columns

# %%
#use replace to remove the special number and replace the inappriopiate value
movies['score'] = movies['score'].astype(str).str.replace(',', '.', regex=False).str.extract(r'(\d+\.?\d*)')[0].astype(float)

#show the dataset
movies.head()
# Out:
#     title_id                     title release_year   genre duration country  \
# 0  tt0111161  The Shawshank Redemption         1995   Drama      142     USA
# 1  tt0068646             The Godfather         1972   Crime      175     USA
# 2  tt0468569           The Dark Knight         2008  Action      152     USA
# 3  tt0071562    The Godfather: Part II         1975   Crime      220     USA
# 4  tt0110912              Pulp Fiction         1994   Crime      154     USA
#
#                content_rating              director         income      votes  \
# 0                  Restricted        Frank Darabont     28,815,245  2,278,845
# 1                  Restricted  Francis Ford Coppola    246,120,974  1,572,674
# 2  Parents Strongly Cautioned     Christopher Nolan  1,005,455,211  2,241,615
# 3                  Restricted  Francis Ford Coppola    408,035,783  1,098,714
# 4                  Restricted     Quentin Tarantino    222,831,817  1,780,147
#
#    score
# 0    9.3
# 1    9.2
# 2    9.0
# 3    9.0
# 4    8.9

# %% [markdown]
# ###  <center>To review the table

# %%
#display the full table
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#show the dataset
movies
# Out:
#       title_id                                              title  \
# 0    tt0111161                           The Shawshank Redemption
# 1    tt0068646                                      The Godfather
# 2    tt0468569                                    The Dark Knight
# 3    tt0071562                             The Godfather: Part II
# 4    tt0110912                                       Pulp Fiction
# 5    tt0167260      The Lord of the Rings: The Return of the King
# 6    tt0108052                                   Schindler's List
# 7    tt0050083                                       12 Angry Men
# 8    tt1375666                                          Inception
# 9    tt0137523                                         Fight Club
# 10   tt0109830                                       Forrest Gump
# 11   tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12   tt0060196                    Il buono, il brutto, il cattivo
# 14   tt0133093                                         The Matrix
# 15   tt0167261              The Lord of the Rings: The Two Towers
# 16   tt0080684     Star Wars: Episode V - The Empire Strikes Back
# 17   tt0099685                                         Goodfellas
# 18   tt0073486                    One Flew Over the Cuckoo's Nest
# 19   tt0816692                                       Interstellar
# 20   tt0114369                                              Se7en
# 21   tt0102926                           The Silence of the Lambs
# 22   tt0076759                                          Star Wars
# 23   tt0120815                                Saving Private Ryan
# 24   tt0120689                                     The Green Mile
# 25   tt0317248                                     Cidade de Deus
# 26   tt0245429                      Sen to Chihiro no kamikakushi
# 27   tt0118799                                   La vita B9 bella
# 28   tt6751668                                       Gisaengchung
# 29   tt0038650                              It's a Wonderful Life
# 30   tt0047478                               Shichinin no samurai
# 31   tt0172495                                          Gladiator
# 32   tt0407887                                       The Departed
# 33   tt0482571                                       The Prestige
# 34   tt0088763                                 Back to the Future
# 35   tt0120586                                 American History X
# 36   tt0110413                                              LÃ©on
# 37   tt0103064                         Terminator 2: Judgment Day
# 38   tt0114814                                 The Usual Suspects
# 39   tt0110357                                      The Lion King
# 40   tt7286456                                              Joker
# 41   tt1675434                                       Intouchables
# 42   tt0253474                                        The Pianist
# 43   tt2582802                                           Whiplash
# 44   tt0054215                                             Psycho
# 45   tt0034583                                         Casablanca
# 46   tt0064116                            C'era una volta il West
# 47   tt0095327                                     Hotaru no haka
# 48   tt0095765                              Nuovo Cinema Paradiso
# 49   tt0027977                                       Modern Times
# 50   tt1345836                              The Dark Knight Rises
# 51   tt1853728                                   Django Unchained
# 52   tt0209144                                            Memento
# 53   tt0910970                                            WALLÂ·E
# 54   tt0081505                                        The Shining
# 55   tt0082971                            Raiders of the Lost Ark
# 56   tt4154756                             Avengers: Infinity War
# 57   tt0078748                                              Alien
# 58   tt4154796                                  Avengers: Endgame
# 59   tt0078788                                     Apocalypse Now
# 60   tt0364569                                           Oldeuboi
# 61   tt0057012  Dr. Strangelove or: How I Learned to Stop Worr...
# 62   tt0047396                                        Rear Window
# 63   tt2380307                                               Coco
# 64   tt0405094                              Das Leben der Anderen
# 65   tt4633694                  Spider-Man: Into the Spider-Verse
# 66   tt1187043                                           3 Idiots
# 67   tt0119698                                      Mononoke-hime
# 68   tt0087843                        Once Upon a Time in America
# 69   tt0032553                                 The Great Dictator
# 70   tt0043014                                       Sunset Blvd.
# 71   tt0361748                               Inglourious Basterds
# 72   tt0169547                                    American Beauty
# 73   tt0112573                                         Braveheart
# 74   tt0086190         Star Wars: Episode VI - Return of the Jedi
# 75   tt0105236                                     Reservoir Dogs
# 76   tt0338013              Eternal Sunshine of the Spotless Mind
# 77   tt0114709                                          Toy Story
# 78   tt0119217                                  Good Will Hunting
# 79   tt0208092                                             Snatch
# 80   tt0180093                                Requiem for a Dream
# 81   tt0066921                                 A Clockwork Orange
# 82   tt0435761                                        Toy Story 3
# 83   tt0086250                                           Scarface
# 84   tt0075314                                        Taxi Driver
# 85   tt0211915               Le fabuleux destin d'AmÃ©lie Poulain
# 86   tt0093058                                  Full Metal Jacket
# 87   tt0090605                                             Aliens
# 88   tt0062622                              2001: A Space Odyssey
# 89   tt0033467                                       Citizen Kane
# 90   tt8579674                                               1917
# 91   tt0086879                                            Amadeus
# 92   tt0052357                                            Vertigo
# 93   tt0053125                                 North by Northwest
# 94   tt2106476                                             Jagten
# 95   tt0056172                                 Lawrence of Arabia
# 96   tt0070735                                          The Sting
# 97   tt0082096                                           Das Boot
# 98   tt0059578                        Per qualche dollaro in piÃ¹
# 99   tt1832382                            Jodaeiye Nader az Simin
# 100  tt0045152                                Singin' in the Rain
#
#     release_year      genre duration       country  \
# 0           1995      Drama      142           USA
# 1           1972      Crime      175           USA
# 2           2008     Action      152           USA
# 3           1975      Crime      220           USA
# 4           1994      Crime      154           USA
# 5           2003     Action      201   New Zealand
# 6           1994  Biography      195           USA
# 7           1957      Crime       96           USA
# 8           2010     Action      148           USA
# 9           1999      Drama      139            UK
# 10          1994      Drama      142           USA
# 11          2002     Action      178   New Zealand
# 12          1966    Western      161         Italy
# 14          1999     Action      136           USA
# 15          2001     Action      179   New Zealand
# 16          1980     Action      124           USA
# 17          1990  Biography      146           USA
# 18          1976      Drama      133           USA
# 19          2014  Adventure      169           USA
# 20          1995      Crime      127           USA
# 21          1991      Crime      118           USA
# 22          1977     Action      121           USA
# 23          1998      Drama      169           USA
# 24          2000      Crime      189           USA
# 25          2003      Crime      130        Brazil
# 26          2003  Animation      125         Japan
# 27          1997     Comedy      116         Italy
# 28          2019     Comedy      132   South Korea
# 29          1948      Drama      130           USA
# 30          1955     Action      207         Japan
# 31          2000     Action      155           USA
# 32          2006      Crime      151           USA
# 33          2006      Drama      130            UK
# 34          1985  Adventure      116           USA
# 35          1999      Drama      119           USA
# 36          1995     Action      110        France
# 37          1991     Action      137           USA
# 38          1995      Crime      106           USA
# 39          1994  Animation       88           USA
# 40          2019      Crime      122           USA
# 41          2012  Biography      112        France
# 42          2002  Biography      150            UK
# 43          2015      Drama      106           USA
# 44          1960     Horror      109           USA
# 45          1943      Drama      102           USA
# 46          1968    Western      165         Italy
# 47          2015  Animation       89         Japan
# 48          1988      Drama      155         Italy
# 49          1937     Comedy       87           USA
# 50          2012     Action      164            UK
# 51          2013      Drama      165           USA
# 52          2001    Mystery      113           USA
# 53          2008  Animation       98           USA
# 54          1980      Drama      146            UK
# 55          1981     Action      115           USA
# 56          2018     Action      149           USA
# 57          1979     Horror      117            UK
# 58          2019     Action      181           USA
# 59          1979      Drama      147           USA
# 60          2005     Action      120   South Korea
# 61          1964     Comedy       95            UK
# 62          1955    Mystery      112           USA
# 63          2017  Animation      105           USA
# 64          2007      Drama      137       Germany
# 65          2018  Animation      117           USA
# 66          2009     Comedy      170         India
# 67          2000  Animation      134         Japan
# 68          1984      Crime      229           USA
# 69          1945     Comedy      125           USA
# 70          1951      Drama      110           USA
# 71          2009  Adventure      153       Germany
# 72          2000      Drama      122           USA
# 73          1995  Biography      178           USA
# 74          1983     Action      131           USA
# 75          1992      Crime       99           USA
# 76          2004      Drama      108           USA
# 77          1996  Animation       81           USA
# 78          1998      Drama      126           USA
# 79          2001     Comedy      104            UK
# 80          2000      Drama      102           USA
# 81          1972      Crime      136            UK
# 82          2010  Animation      103           USA
# 83          1984      Crime      170           USA
# 84          1976      Crime      114           USA
# 85          2002     Comedy      122        France
# 86          1987      Drama      116            UK
# 87          1986     Action      137           USA
# 88          1968  Adventure      149            UK
# 89          1948      Drama      119           USA
# 90          2020      Drama      119           USA
# 91          1985  Biography      160           USA
# 92          1958    Mystery      128           USA
# 93          1959  Adventure      136           USA
# 94          2012      Drama      115       Denmark
# 95          1963  Adventure      228            UK
# 96          1974     Comedy      129           USA
# 97          1982  Adventure      149  West Germany
# 98          1965    Western      132         Italy
# 99          2011      Drama      123          Iran
# 100         1953     Comedy      103           USA
#
#                  content_rating                          director  \
# 0                    Restricted                    Frank Darabont
# 1                    Restricted              Francis Ford Coppola
# 2    Parents Strongly Cautioned                 Christopher Nolan
# 3                    Restricted              Francis Ford Coppola
# 4                    Restricted                 Quentin Tarantino
# 5    Parents Strongly Cautioned                     Peter Jackson
# 6                    Restricted                  Steven Spielberg
# 7                     Not Rated                      Sidney Lumet
# 8    Parents Strongly Cautioned                 Christopher Nolan
# 9                    Restricted                     David Fincher
# 10   Parents Strongly Cautioned                   Robert Zemeckis
# 11   Parents Strongly Cautioned                     Peter Jackson
# 12                      General                      Sergio Leone
# 14                   Restricted   Lana Wachowski, Lilly Wachowski
# 15   Parents Strongly Cautioned                     Peter Jackson
# 16            Parental Guidance                    Irvin Kershner
# 17                   Restricted                   Martin Scorsese
# 18                   Restricted                      Milos Forman
# 19   Parents Strongly Cautioned                 Christopher Nolan
# 20                   Restricted                     David Fincher
# 21                   Restricted                    Jonathan Demme
# 22            Parental Guidance                      George Lucas
# 23                   Restricted                  Steven Spielberg
# 24                   Restricted                    Frank Darabont
# 25                   Restricted   Fernando Meirelles, KÃ¡tia Lund
# 26            Parental Guidance                    Hayao Miyazaki
# 27                    Not rated                   Roberto Benigni
# 28                    Not rated                      Bong Joon Ho
# 29            Parental Guidance                       Frank Capra
# 30                    Not Rated                    Akira Kurosawa
# 31                   Restricted                      Ridley Scott
# 32                   Restricted                   Martin Scorsese
# 33   Parents Strongly Cautioned                 Christopher Nolan
# 34            Parental Guidance                   Robert Zemeckis
# 35                   Restricted                         Tony Kaye
# 36                    Not rated                        Luc Besson
# 37                   Restricted                     James Cameron
# 38                   Restricted                      Bryan Singer
# 39                      General         Roger Allers, Rob Minkoff
# 40                    Not rated                     Todd Phillips
# 41                    Not rated   Olivier Nakache, Ãric Toledano
# 42                   Restricted                    Roman Polanski
# 43                   Restricted                   Damien Chazelle
# 44                   Restricted                  Alfred Hitchcock
# 45            Parental Guidance                    Michael Curtiz
# 46   Parents Strongly Cautioned                      Sergio Leone
# 47                    Not rated                     Isao Takahata
# 48                    Not rated                Giuseppe Tornatore
# 49                      General                   Charles Chaplin
# 50   Parents Strongly Cautioned                 Christopher Nolan
# 51                   Restricted                 Quentin Tarantino
# 52                   Restricted                 Christopher Nolan
# 53                      General                    Andrew Stanton
# 54                   Restricted                   Stanley Kubrick
# 55            Parental Guidance                  Steven Spielberg
# 56                    Not rated          Anthony Russo, Joe Russo
# 57                   Restricted                      Ridley Scott
# 58                    Not rated          Anthony Russo, Joe Russo
# 59                   Restricted              Francis Ford Coppola
# 60                   Restricted                    Chan-wook Park
# 61            Parental Guidance                   Stanley Kubrick
# 62                    Not rated                  Alfred Hitchcock
# 63                    Not rated        Lee Unkrich, Adrian Molina
# 64                   Restricted  Florian Henckel von Donnersmarck
# 65                    Not rated     Bob Persichetti, Peter Ramsey
# 66                    Not rated                   Rajkumar Hirani
# 67   Parents Strongly Cautioned                    Hayao Miyazaki
# 68                   Restricted                      Sergio Leone
# 69                    Not rated                   Charles Chaplin
# 70                    Not rated                      Billy Wilder
# 71                   Restricted                 Quentin Tarantino
# 72                   Restricted                        Sam Mendes
# 73                   Restricted                        Mel Gibson
# 74            Parental Guidance                  Richard Marquand
# 75                   Restricted                 Quentin Tarantino
# 76                   Restricted                     Michel Gondry
# 77                      General                     John Lasseter
# 78                   Restricted                      Gus Van Sant
# 79                   Restricted                       Guy Ritchie
# 80                   Restricted                  Darren Aronofsky
# 81                    Not rated                   Stanley Kubrick
# 82                      General                       Lee Unkrich
# 83                   Restricted                    Brian De Palma
# 84                   Restricted                   Martin Scorsese
# 85                   Restricted                Jean-Pierre Jeunet
# 86                    Not rated                   Stanley Kubrick
# 87                   Restricted                     James Cameron
# 88                      General                   Stanley Kubrick
# 89                    Not rated                      Orson Welles
# 90                    Not rated                        Sam Mendes
# 91                   Restricted                      Milos Forman
# 92                    Not rated                  Alfred Hitchcock
# 93                    Not rated                  Alfred Hitchcock
# 94                   Restricted                 Thomas Vinterberg
# 95            Parental Guidance                        David Lean
# 96            Parental Guidance                   George Roy Hill
# 97                   Restricted                 Wolfgang Petersen
# 98                    Not rated                      Sergio Leone
# 99   Parents Strongly Cautioned                    Asghar Farhadi
# 100                   Not rated                     Stanley Donen
#
#              income      votes  score
# 0        28,815,245  2,278,845    9.3
# 1       246,120,974  1,572,674    9.2
# 2     1,005,455,211  2,241,615    9.0
# 3       408,035,783  1,098,714    9.0
# 4       222,831,817  1,780,147    8.9
# 5     1,142,271,098  1,604,280    8.9
# 6       322,287,794  1,183,248    8.9
# 7               576    668,473    8.9
# 8       869,784,991  2,002,816    8.0
# 9       101,218,804  1,807,440    8.8
# 10      678,229,452  1,755,490    8.0
# 11      887,934,303  1,619,920    8.8
# 12       25,252,481    672,499    8.8
# 14      465,718,588  1,632,315    8.7
# 15      951,227,416  1,449,778    8.7
# 16      549,265,501  1,132,073    8.7
# 17       46,879,633    991,505    8.7
# 18      108,997,629    891,071    8.7
# 19      696,742,056  1,449,256    8.6
# 20      327,333,559  1,402,015    8.6
# 21      272,753,884  1,234,134    8.6
# 22      775,768,912  1,204,107    8.6
# 23      482,349,603  1,203,825    8.6
# 24      286,801,374  1,112,336    8.6
# 25       30,680,793    685,856    8.6
# 26      355,467,056    626,693    8.6
# 27      230,098,753    605,648    8.6
# 28      257,604,912    470,931    8.6
# 29        6,130,720    388,310    8.6
# 30          322,773    307,958    8.6
# 31      465,361,176  1,308,193    8.5
# 32      291,465,034  1,159,703    8.5
# 33      109,676,311  1,155,723    8.5
# 34      388,774,684  1,027,330    8.5
# 35       23,875,127  1,014,218    8.5
# 36       19,552,639  1,007,598    8.5
# 37      520,884,847    974,970    8.4
# 38       23,341,568    968,947    8.4
# 39      968,511,805    917,248    8.4
# 40    1,074,251,311    855,097    8.4
# 41      426,588,510    736,691    8.4
# 42      120,072,577    707,942    8.4
# 43       48,983,260    690,732    8.4
# 44       32,008,644    586,765    8.3
# 45        4,374,761    509,953    8.3
# 46          112,911    295,220    8.3
# 47          516,962    225,438    8.3
# 48       13,826,605    223,050    8.3
# 49          457,688    211,250    8.3
# 50    1,081,133,191  1,480,582    8.3
# 51      425,368,238  1,317,856    8.3
# 52       39,970,386  1,098,879    8.2
# 53      521,311,860    974,734    8.2
# 54       46,520,613    869,480    8.2
# 55      390,133,212    865,510    8.2
# 56    2,048,359,754    796,486    8.2
# 57      108,110,316    768,874    8.2
# 58   -2,147,483,648    754,786    8.2
# 59       91,968,688    591,251    8.2
# 60       15,002,116    501,082    8.1
# 61        9,443,876    441,115    8.1
# 62       37,032,034    432,390    8.1
# 63      807,083,670    352,455    8.1
# 64       77,356,942    349,642    8.1
# 65      375,540,831    335,892    8.1
# 66       60,262,836    332,217    8.1
# 67      169,785,629    331,045    8.0
# 68        5,472,914    302,317    8.0
# 69          969,879    197,381    8.0
# 70          299,645    195,789    8.0
# 71      321,455,689  1,229,958    8.0
# 72      356,296,601  1,049,009    8.0
# 73      213,216,216    941,683    7.9
# 74      475,347,111    928,036    7.9
# 75        2,889,963    896,551    7.9
# 76       74,036,715    889,875    7.9
# 77      404,265,438    864,461    7.9
# 78      225,933,435    837,379    7.8
# 79       83,557,872    766,589    7.8
# 80        7,390,108    748,291    7.8
# 81       26,903,440    740,301    7.8
# 82    1,066,969,703    739,717    7.8
# 83       66,023,585    721,343    7.8
# 84       28,441,292    703,264    7.7
# 85      173,924,742    690,480    7.7
# 86       46,357,676    658,175    7.7
# 87      131,384,634    639,500    7.7
# 88       68,989,547    587,866    7.6
# 89        1,594,107    389,322    7.6
# 90      384,857,224    362,897    7.6
# 91       52,066,791    361,028    7.6
# 92        7,796,389    352,786    7.5
# 93           73,446    291,628    7.5
# 94       15,843,274    269,616    7.5
# 95       45,710,874    261,504    7.5
# 96      156,000,000    236,285    7.5
# 97       11,487,676    226,427    7.5
# 98       15,000,000    226,039    7.4
# 99       22,926,076    214,165    7.4
# 100       1,864,182    213,152    7.4

# %%
#save the updated dataset
movies.to_csv('movies_updated.csv')
